# %%
#EXPLORITY OF DATA ANALYTICS ON COASTER DATA
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as mat
mat.style.use('ggplot')
#pd.set_option('max_columns', 200)

# %%
df=pd.read_csv("/content/coaster_db.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.isnull()
# Out:
#       coaster_name  Length  Speed  Location  Status  Opening date   Type  \
# 0            False   False  False     False   False         False  False
# 1            False    True   True     False   False         False  False
# 2            False    True   True     False   False          True  False
# 3            False    True   True     False   False         False  False
# 4            False    True   True     False   False         False  False
# ...            ...     ...    ...       ...     ...           ...    ...
# 1082         False   False  False     False    True          True  False
# 1083         False   False  False     False   False         False  False
# 1084         False   False  False     False    True         False  False
# 1085         False   False  False     False   False          True  False
# 1086         False   False  False     False   False         False  False
#
#       Manufacturer  Height restriction  Model  ...  speed1  speed2  \
# ...

# %%
df.isnull().sum()
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      250
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                 991
# Fast Lane available              1018
# Replaced                          914
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df['Location'].count()
# Out:
# 1087

# %% [markdown]
# # DATA VIZULIZATION USING HISTOGRAM AND BAR PIECHARTS

# %%
df.rename(columns={'Type':'TYPE'})
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df.loc[df.duplicated(subset=['coaster_name'])]
# Out:
#                             coaster_name                Length  \
# 43                 Crystal Beach Cyclone      2,953 ft (900 m)
# 60                           Derby Racer                   NaN
# 61           Blue Streak (Conneaut Lake)      2,900 ft (880 m)
# 167        Big Thunder Mountain Railroad                   NaN
# 237    Thunder Run (Canada's Wonderland)      330 m (1,080 ft)
# ...                                  ...                   ...
# 1063                  Lil' Devil Coaster     262.5 ft (80.0 m)
# 1064  Little Dipper (Conneaut Lake Park)                   NaN
# 1080                          Iron Gwazi    4,075 ft (1,242 m)
# 1082             American Dreier Looping    3,444 ft (1,050 m)
# 1084           Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
#
#                         Speed                   Location              Status  \
# 43           60 mph (97 km/h)         Crystal Beach Park             Removed
# ...

# %%
df.query('coaster_name == "Tron Lightcycle Power Run"') ## here checking a details duplicated
# Out:
#                    coaster_name                Length  \
# 978   Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1084  Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
#
#                         Speed Location Status   Opening date  \
# 978   59.3[1] mph (95.4 km/h)    Other    NaN  June 16, 2016
# 1084  59.3[1] mph (95.4 km/h)    Other    NaN  June 16, 2016
#
#                   Type Manufacturer Height restriction  \
# 978   Steel – Launched       Vekoma   4[2] ft (122 cm)
# 1084  Steel – Launched       Vekoma   4[2] ft (122 cm)
#
#                          Model  ...     speed1     speed2 speed1_value  \
# 978   Motorbike roller coaster  ...  59.3 mph   95.4 km/h         59.3
# 1084  Motorbike roller coaster  ...  59.3 mph   95.4 km/h         59.3
#
#      speed1_unit speed_mph height_value height_unit height_ft  \
# 978          mph      59.3         78.1          ft       NaN
# 1084         mph      59.3         78.1          ft       NaN
#
# ...

# %%
ax = df['speed1'].value_counts()  \
.head(10) \
.plot(kind='pie', title='speed moved by the coaster')

# %%
pd.to_numeric(df["longitude"])
# Out:
# 0      -73.9780
# 1      -73.9790
# 2      -81.5700
# 3      -73.9780
# 4      -74.4342
#          ...
# 1082        NaN
# 1083   -76.6426
# 1084        NaN
# 1085        NaN
# 1086        NaN
# Name: longitude, Length: 1087, dtype: float64

# %%
ax = df['year_introduced'].value_counts() \
    .head(10) \
    .plot(kind='bar', title='Top 10 Years Coasters Introduced')
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['speed_mph'].plot(kind='hist',
                          bins=20,
                          title='here calculating a speed in miles per hour')
ax.set_xlabel("mph")
ax.set_ylabel("by speed")
# Out:
# Text(0, 0.5, 'by speed')

# %%
ax = df['speed_mph'].plot(kind='kde',
                          title='here calculating a speed in miles per hour')
ax.set_xlabel("mph")
ax.set_ylabel("by speed")
# Out:
# Text(0, 0.5, 'by speed')

# %% [markdown]
# FUTURE RELATION SHIP
# SCATTER PLOT
# PAIR PLOT
# HEATMAP
# GROUP BY COMAPRISIONS

# %%
result = df.groupby(['coaster_name'])['Cost'].count().sort_values(ascending=False)

# %%
result_df = result.reset_index()

# %%
new_var = sbn.barplot(x='coaster_name', y='Cost', data = result_df)

# %%
df.plot(kind='scatter',
        x='Speed',
        y='Height',
        title='Coaster Speed vs. Height')
mat.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-0f7fb673fb3e> in <cell line: 1>()
# ----> 1 df.plot(kind='scatter',
#       2         x='Speed',
#       3         y='Height',
#       4         title='Coaster Speed vs. Height')
#       5 mat.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918         if kind in self._dataframe_kinds:
#     919             if isinstance(data, ABCDataFrame):
# --> 920                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     921             else:
#     922                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
df['year_introduced']>10
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1082    True
# 1083    True
# 1084    True
# 1085    True
# 1086    True
# Name: year_introduced, Length: 1087, dtype: bool
